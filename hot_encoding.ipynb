# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from feature_engine.categorical_encoders import OneHotCategoricalEncoder

# %%
data = pd.read_csv('C:/Users/Pedro/Desktop/Feature Engineering/titanic.csv', usecols=['sex',
                                                                                     'embarked',
                                                                                     'cabin',
                                                                                     'survived'])
data.head()
# Out:
#    survived     sex cabin embarked
# 0         1  female    B5        S
# 1         1    male   C22        S
# 2         0  female   C22        S
# 3         0    male   C22        S
# 4         0  female   C22        S

# %%
data['cabin'] = data['cabin'].str[0]
data.head()
# Out:
#    survived     sex cabin embarked
# 0         1  female     B        S
# 1         1    male     C        S
# 2         0  female     C        S
# 3         0    male     C        S
# 4         0  female     C        S

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data[['sex', 'embarked', 'cabin']],  # predictors
    data['survived'],  # target
    test_size=0.3,  # percentage of obs in test set
    random_state=0)  # seed to ensure reproducibility

X_train.shape, X_test.shape
# Out:
# ((916, 3), (393, 3))

# %%
# explore cardinality
X_train['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
X_train['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
X_train['cabin'].unique()
# Out:
# array([nan, 'E', 'C', 'D', 'B', 'A', 'F', 'T', 'G'], dtype=object)

# %%
tmp = pd.get_dummies(X_train['sex'])
tmp.head()
# Out:
#       female  male
# 501        1     0
# 588        1     0
# 402        1     0
# 1193       0     1
# 686        1     0

# %%
pd.concat([X_train['sex'],
         pd.get_dummies(X_train['sex'])], axis=1).head()
# Out:
#          sex  female  male
# 501   female       1     0
# 588   female       1     0
# 402   female       1     0
# 1193    male       0     1
# 686   female       1     0

# %%
tmp = pd.get_dummies(X_train['embarked'])

tmp.head()
# Out:
#       C  Q  S
# 501   0  0  1
# 588   0  0  1
# 402   1  0  0
# 1193  0  1  0
# 686   0  1  0

# %%
pd.concat([X_train['embarked'],
           pd.get_dummies(X_train['embarked'])], axis=1).head()
# Out:
#      embarked  C  Q  S
# 501         S  0  0  1
# 588         S  0  0  1
# 402         C  1  0  0
# 1193        Q  0  1  0
# 686         Q  0  1  0

# %%
tmp = pd.get_dummies(X_train['cabin'])
tmp.head()
# Out:
#       A  B  C  D  E  F  G  T
# 501   0  0  0  0  0  0  0  0
# 588   0  0  0  0  0  0  0  0
# 402   0  0  0  0  0  0  0  0
# 1193  0  0  0  0  0  0  0  0
# 686   0  0  0  0  0  0  0  0

# %%
tmp = pd.get_dummies(X_train)
print(tmp.shape)
tmp.head()
# Out:
# (916, 13)
#       sex_female  sex_male  embarked_C  embarked_Q  embarked_S  cabin_A  \
# 501            1         0           0           0           1        0
# 588            1         0           0           0           1        0
# 402            1         0           1           0           0        0
# 1193           0         1           0           1           0        0
# 686            1         0           0           1           0        0
#
#       cabin_B  cabin_C  cabin_D  cabin_E  cabin_F  cabin_G  cabin_T
# 501         0        0        0        0        0        0        0
# 588         0        0        0        0        0        0        0
# 402         0        0        0        0        0        0        0
# 1193        0        0        0        0        0        0        0
# 686         0        0        0        0        0        0        0

# %%
tmp = pd.get_dummies(X_test)
print(tmp.shape)
tmp.head()
# Out:
# (393, 12)
#       sex_female  sex_male  embarked_C  embarked_Q  embarked_S  cabin_A  \
# 1139           0         1           0           0           1        0
# 533            1         0           0           0           1        0
# 459            0         1           0           0           1        0
# 1150           0         1           0           0           1        0
# 393            0         1           0           0           1        0
#
#       cabin_B  cabin_C  cabin_D  cabin_E  cabin_F  cabin_G
# 1139        0        0        0        0        0        0
# 533         0        0        0        0        0        0
# 459         0        0        0        0        0        0
# 1150        0        0        0        0        0        0
# 393         0        0        0        0        0        0

# %%
tmp = pd.get_dummies(X_train['sex'], drop_first=True)

tmp.head()
# Out:
#       male
# 501      0
# 588      0
# 402      0
# 1193     1
# 686      0

# %%
tmp = pd.get_dummies(X_train['embarked'], drop_first=True)

tmp.head()
# Out:
#       Q  S
# 501   0  1
# 588   0  1
# 402   0  0
# 1193  1  0
# 686   1  0

# %%
tmp = pd.get_dummies(X_train, drop_first=True)

print(tmp.shape)

tmp.head()
# Out:
# (916, 10)
#       sex_male  embarked_Q  embarked_S  cabin_B  cabin_C  cabin_D  cabin_E  \
# 501          0           0           1        0        0        0        0
# 588          0           0           1        0        0        0        0
# 402          0           0           0        0        0        0        0
# 1193         1           1           0        0        0        0        0
# 686          0           1           0        0        0        0        0
#
#       cabin_F  cabin_G  cabin_T
# 501         0        0        0
# 588         0        0        0
# 402         0        0        0
# 1193        0        0        0
# 686         0        0        0

# %%
tmp = pd.get_dummies(X_test, drop_first=True)

print(tmp.shape)

tmp.head()
# Out:
# (393, 9)
#       sex_male  embarked_Q  embarked_S  cabin_B  cabin_C  cabin_D  cabin_E  \
# 1139         1           0           1        0        0        0        0
# 533          0           0           1        0        0        0        0
# 459          1           0           1        0        0        0        0
# 1150         1           0           1        0        0        0        0
# 393          1           0           1        0        0        0        0
#
#       cabin_F  cabin_G
# 1139        0        0
# 533         0        0
# 459         0        0
# 1150        0        0
# 393         0        0

# %%
pd.get_dummies(X_train['embarked'], drop_first=True, dummy_na=True).head()
# Out:
#       Q  S  NaN
# 501   0  1    0
# 588   0  1    0
# 402   0  0    0
# 1193  1  0    0
# 686   1  0    0

# %%
encoder = OneHotEncoder(categories='auto',
                       drop='first', # to return k-1, use drop=false to return k dummies
                       sparse=False,
                       handle_unknown='ignore') # helps deal with rare labels

encoder.fit(X_train.fillna('Missing'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-662258585efb> in <module>
#       4                        handle_unknown='ignore') # helps deal with rare labels
#       5
# ----> 6 encoder.fit(X_train.fillna('Missing'))
#
# ~\Anaconda3\envs\feature_engineering\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     481         """
#     482
# --> 483         self._validate_keywords()
#     484
#     485         self._handle_deprecations(X)
#
# ~\Anaconda3\envs\feature_engineering\lib\site-packages\sklearn\preprocessing\_encoders.py in _validate_keywords(self)
#     541         if self.drop is not None and self.handle_unknown != 'error':
#     542             raise ValueError(
# --> 543                 "`handle_unknown` must be 'error' when the drop parameter is "
#     544                 "specified, as both would create categories that are all "
#     545                 "zero.")
#
# ValueError: `handle_unknown` must be 'error' when the drop parameter is specified, as both would create categories that are all zero.
